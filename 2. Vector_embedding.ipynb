# %% [markdown]
# <a href="https://colab.research.google.com/github/sugam24/GPT-2_FROM_SCRATCH/blob/main/2.%20Vector_embedding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This file is just to experience the trained vector embeddings model word2vec.

# %%
# !pip install gensim

# %% [markdown]
# # Import trained model

# %%
import gensim.downloader as api
model = api.load("word2vec-google-news-300")  # download the model and return as object ready for use
# Out:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded

# %% [markdown]
# # Example of a word as a vector

# %%
word_vectors=model

# Let us look how the vector embedding of a word looks like
print(word_vectors['apple'])  # Example: Accessing the vector for the word 'apple'
# Out:
# [-0.06445312 -0.16015625 -0.01208496  0.13476562 -0.22949219  0.16210938
#   0.3046875  -0.1796875  -0.12109375  0.25390625 -0.01428223 -0.06396484
#  -0.08056641 -0.05688477 -0.19628906  0.2890625  -0.05151367  0.14257812
#  -0.10498047 -0.04736328 -0.34765625  0.35742188  0.265625    0.00188446
#  -0.01586914  0.00195312 -0.35546875  0.22167969  0.05761719  0.15917969
#   0.08691406 -0.0267334  -0.04785156  0.23925781 -0.05981445  0.0378418
#   0.17382812 -0.41796875  0.2890625   0.32617188  0.02429199 -0.01647949
#  -0.06494141 -0.08886719  0.07666016 -0.15136719  0.05249023 -0.04199219
#  -0.05419922  0.00108337 -0.20117188  0.12304688  0.09228516  0.10449219
#  -0.00408936 -0.04199219  0.01409912 -0.02111816 -0.13476562 -0.24316406
#   0.16015625 -0.06689453 -0.08984375 -0.07177734 -0.00595093 -0.00482178
#  -0.00089264 -0.30664062 -0.0625      0.07958984 -0.00909424 -0.04492188
#   0.09960938 -0.33398438 -0.3984375   0.05541992 -0.06689453 -0.04467773
# ...

# %%
print(word_vectors['apple'].shape)
# Out:
# (300,)

# %% [markdown]
# # Similar words

# %% [markdown]
# # King + Woman - Man = ?

# %%
# Example of using most_similar
print(word_vectors.most_similar(positive=['king', 'woman'], negative=['man'], topn=10))
# Out:
# [('queen', 0.7118193507194519), ('monarch', 0.6189674139022827), ('princess', 0.5902431011199951), ('crown_prince', 0.5499460697174072), ('prince', 0.5377321839332581), ('kings', 0.5236844420433044), ('Queen_Consort', 0.5235945582389832), ('queens', 0.518113374710083), ('sultan', 0.5098593235015869), ('monarchy', 0.5087411403656006)]

# %% [markdown]
# # Let us check the similarity b/w a few pair of words

# %%
# Example of calculating similarity
print(word_vectors.similarity('woman', 'man'))
print(word_vectors.similarity('king', 'queen'))
print(word_vectors.similarity('uncle', 'aunt'))
print(word_vectors.similarity('boy', 'girl'))
print(word_vectors.similarity('nephew', 'niece'))
print(word_vectors.similarity('brother', 'sister'))
print(word_vectors.similarity('mountain', 'hills'))
print(word_vectors.similarity('engineer', 'unemployed'))
print(word_vectors.similarity('doctor', 'unemployed'))
print(word_vectors.similarity('paper', 'water'))
print(word_vectors.similarity('tiger', 'are'))
# Out:
# 0.76640123
# 0.6510957
# 0.7643474
# 0.8543272
# 0.7594367
# 0.71603835
# 0.6330643
# 0.1820999
# 0.12601264
# 0.11408084
# 0.041931394

# %% [markdown]
# # Most similar words

# %%
print(word_vectors.most_similar("engineer", topn=5))
# Out:
# [('electrical_engineer', 0.7500534653663635), ('mechanical_engineer', 0.7456685304641724), ('Engineer', 0.6911254525184631), ('engineering', 0.6766180396080017), ('engineeer', 0.611038863658905)]

# %% [markdown]
# # Now let us see the vector similarity

# %%
import numpy as np
# Words to compare
word1 = 'man'
word2 = 'woman'

word3 = 'semiconductor'
word4 = 'earthworm'

word5 = 'terrorist'
word6 = 'bomb'

# Calculate the vector difference
vector_difference1 = model[word1] - model[word2]
vector_difference2 = model[word3] - model[word4]
vector_difference3 = model[word5] - model[word6]

# Calculate the magnitude of the vector difference
magnitude_of_difference1 = np.linalg.norm(vector_difference1)
magnitude_of_difference2 = np.linalg.norm(vector_difference2)
magnitude_of_difference3 = np.linalg.norm(vector_difference3)


# Print the magnitude of the difference
print("The magnitude of the difference between '{}' and '{}' is {:.2f}".format(word1, word2, magnitude_of_difference1))
print("The magnitude of the difference between '{}' and '{}' is {:.2f}".format(word3, word4, magnitude_of_difference2))
print("The magnitude of the difference between '{}' and '{}' is {:.2f}".format(word5, word6, magnitude_of_difference3))
# Out:
# The magnitude of the difference between 'man' and 'woman' is 1.73
# The magnitude of the difference between 'semiconductor' and 'earthworm' is 5.67
# The magnitude of the difference between 'terrorist' and 'bomb' is 3.97
